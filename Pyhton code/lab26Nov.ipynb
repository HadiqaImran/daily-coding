# %%
patients_data = [
"id:1,name:Ali Khan,age:45,doctor:Dr. Ahmed,hr:88,bp:120/80,glucose:110,feedback:Good",
"id:2,name:Ayesha Noor,age:63,doctor:Dr. Sara,hr:102,bp:145/95,glucose:160,feedback:Critical",
"id:3,name:Usman Tariq,age:52,doctor:Dr. Ahmed,hr:76,bp:118/78,glucose:95,feedback:Excellent",
"id:4,name:Sana Fatima,age:29,doctor:Dr. Bilal,hr:91,bp:130/85,glucose:125,feedback:Good",
"id:5,name:Hamza Ali,age:38,doctor:Dr. Sara,hr:110,bp:150/92,glucose:180,feedback:Critical",
"id:6,name:Maryam Iqbal,age:71,doctor:Dr. Ahmed,hr:82,bp:135/88,glucose:140,feedback:Fair",
"id:7,name:Imran Hussain,age:66,doctor:Dr. Noor,hr:97,bp:142/90,glucose:165,feedback:Fair",
"id:8,name:Rida Aslam,age:54,doctor:Dr. Sara,hr:105,bp:149/94,glucose:172,feedback:Critical",
"id:9,name:Hassan Raza,age:27,doctor:Dr. Ahmed,hr:72,bp:117/79,glucose:88,feedback:Excellent",
"id:10,name:Fatima Sheikh,age:44,doctor:Dr. Bilal,hr:95,bp:134/89,glucose:130,feedback:Good",
"id:11,name:Bilal Khan,age:61,doctor:Dr. Sara,hr:99,bp:140/92,glucose:155,feedback:Fair",
"id:12,name:Khadija Amin,age:36,doctor:Dr. Ahmed,hr:85,bp:128/84,glucose:115,feedback:Good",
"id:13,name:Zain Ali,age:70,doctor:Dr. Noor,hr:101,bp:147/93,glucose:162,feedback:Critical",
"id:14,name:Sara Usman,age:48,doctor:Dr. Bilal,hr:78,bp:122/80,glucose:100,feedback:Excellent",
"id:15,name:Adeel Ahmad,age:55,doctor:Dr. Ahmed,hr:92,bp:130/85,glucose:138,feedback:Fair",
"id:16,name:Lubna Tariq,age:32,doctor:Dr. Sara,hr:87,bp:125/83,glucose:120,feedback:Good",
"id:17,name:Irfan Malik,age:68,doctor:Dr. Noor,hr:108,bp:150/95,glucose:175,feedback:Critical",
"id:18,name:Raheel Khan,age:40,doctor:Dr. Ahmed,hr:74,bp:119/77,glucose:93,feedback:Excellent",
"id:19,name:Saima Noor,age:59,doctor:Dr. Bilal,hr:90,bp:136/90,glucose:143,feedback:Fair",
"id:20,name:Taha Salman,age:25,doctor:Dr. Sara,hr:83,bp:121/81,glucose:108,feedback:Good",
"id:21,name:Hira Asghar,age:47,doctor:Dr. Ahmed,hr:96,bp:140/91,glucose:150,feedback:Fair",
"id:22,name:Zara Malik,age:33,doctor:Dr. Noor,hr:70,bp:115/75,glucose:85,feedback:Excellent",
"id:23,name:Rizwan Ali,age:62,doctor:Dr. Bilal,hr:104,bp:150/96,glucose:168,feedback:Critical",
"id:24,name:Shazia Ahmed,age:58,doctor:Dr. Sara,hr:88,bp:129/84,glucose:118,feedback:Good",
"id:25,name:Muhammad Iqbal,age:42,doctor:Dr. Ahmed,hr:76,bp:116/78,glucose:97,feedback:Excellent",
"id:26,name:Neha Khan,age:37,doctor:Dr. Noor,hr:91,bp:132/86,glucose:135,feedback:Good",
"id:27,name:Ali Raza,age:69,doctor:Dr. Bilal,hr:107,bp:152/97,glucose:178,feedback:Critical",
"id:28,name:Fahad Saleem,age:51,doctor:Dr. Ahmed,hr:80,bp:124/82,glucose:112,feedback:Good",
"id:29,name:Mahnoor Shah,age:60,doctor:Dr. Sara,hr:98,bp:141/93,glucose:158,feedback:Fair",
"id:30,name:Ammar Tariq,age:30,doctor:Dr. Noor,hr:75,bp:118/78,glucose:92,feedback:Excellent",
"id:31,name:Sana Javed,age:34,doctor:Dr. Bilal,hr:90,bp:130/88,glucose:140,feedback:Fair",
"id:32,name:Mubashir Ali,age:57,doctor:Dr. Ahmed,hr:103,bp:148/94,glucose:170,feedback:Critical",
"id:33,name:Ayesha Khan,age:46,doctor:Dr. Noor,hr:82,bp:125/83,glucose:115,feedback:Good",
"id:34,name:Omer Malik,age:39,doctor:Dr. Sara,hr:86,bp:128/85,glucose:122,feedback:Good",
"id:35,name:Fatima Raza,age:28,doctor:Dr. Ahmed,hr:72,bp:116/79,glucose:97,feedback:Excellent",
"id:36,name:Hammad Sheikh,age:49,doctor:Dr. Bilal,hr:94,bp:137/90,glucose:145,feedback:Fair",
"id:37,name:Saba Malik,age:64,doctor:Dr. Sara,hr:106,bp:151/97,glucose:173,feedback:Critical",
"id:38,name:Asad Ali,age:41,doctor:Dr. Noor,hr:77,bp:120/80,glucose:102,feedback:Good",
"id:39,name:Naima Iqbal,age:56,doctor:Dr. Ahmed,hr:95,bp:139/91,glucose:150,feedback:Fair",
"id:40,name:Waleed Khan,age:62,doctor:Dr. Bilal,hr:109,bp:155/98,glucose:180,feedback:Critical",
"id:41,name:Anam Fatima,age:43,doctor:Dr. Sara,hr:78,bp:122/81,glucose:104,feedback:Good",
"id:42,name:Adeel Qureshi,age:38,doctor:Dr. Ahmed,hr:92,bp:133/87,glucose:138,feedback:Fair",
"id:43,name:Sara Ali,age:29,doctor:Dr. Noor,hr:74,bp:119/78,glucose:96,feedback:Excellent",
"id:44,name:Talha Sharif,age:66,doctor:Dr. Bilal,hr:105,bp:149/96,glucose:168,feedback:Critical",
"id:45,name:Madiha Khan,age:61,doctor:Dr. Ahmed,hr:89,bp:135/89,glucose:142,feedback:Fair",
"id:46,name:Arslan Tariq,age:31,doctor:Dr. Sara,hr:73,bp:116/76,glucose:90,feedback:Excellent",
"id:47,name:Rehan Ahmed,age:52,doctor:Dr. Noor,hr:97,bp:141/92,glucose:152,feedback:Fair",
"id:48,name:Nida Malik,age:48,doctor:Dr. Bilal,hr:95,bp:138/90,glucose:148,feedback:Good",
"id:49,name:Salman Khan,age:40,doctor:Dr. Ahmed,hr:84,bp:124/83,glucose:118,feedback:Good",
"id:50,name:Uzma Raza,age:58,doctor:Dr. Sara,hr:103,bp:146/95,glucose:169,feedback:Critical"
]
structured_data = []

for data in (patients_data):
    parts = data.split(',')
    Patient_data = {}
    for part in parts:
        key, value = part.split(':', 1)
        Patient_data[key] = value
    Patient_data['id'] = int(Patient_data['id'])
    Patient_data['age'] = int(Patient_data['age'])
    Patient_data['glucose'] = int(Patient_data['glucose'])
    Patient_data['hr'] = int(Patient_data['hr'])
    
   
    
    structured_data.append(Patient_data)
    print(f" {Patient_data}")
# Out:
#  {'id': 1, 'name': 'Ali Khan', 'age': 45, 'doctor': 'Dr. Ahmed', 'hr': 88, 'bp': '120/80', 'glucose': 110, 'feedback': 'Good'}
#  {'id': 2, 'name': 'Ayesha Noor', 'age': 63, 'doctor': 'Dr. Sara', 'hr': 102, 'bp': '145/95', 'glucose': 160, 'feedback': 'Critical'}
#  {'id': 3, 'name': 'Usman Tariq', 'age': 52, 'doctor': 'Dr. Ahmed', 'hr': 76, 'bp': '118/78', 'glucose': 95, 'feedback': 'Excellent'}
#  {'id': 4, 'name': 'Sana Fatima', 'age': 29, 'doctor': 'Dr. Bilal', 'hr': 91, 'bp': '130/85', 'glucose': 125, 'feedback': 'Good'}
#  {'id': 5, 'name': 'Hamza Ali', 'age': 38, 'doctor': 'Dr. Sara', 'hr': 110, 'bp': '150/92', 'glucose': 180, 'feedback': 'Critical'}
#  {'id': 6, 'name': 'Maryam Iqbal', 'age': 71, 'doctor': 'Dr. Ahmed', 'hr': 82, 'bp': '135/88', 'glucose': 140, 'feedback': 'Fair'}
#  {'id': 7, 'name': 'Imran Hussain', 'age': 66, 'doctor': 'Dr. Noor', 'hr': 97, 'bp': '142/90', 'glucose': 165, 'feedback': 'Fair'}
#  {'id': 8, 'name': 'Rida Aslam', 'age': 54, 'doctor': 'Dr. Sara', 'hr': 105, 'bp': '149/94', 'glucose': 172, 'feedback': 'Critical'}
#  {'id': 9, 'name': 'Hassan Raza', 'age': 27, 'doctor': 'Dr. Ahmed', 'hr': 72, 'bp': '117/79', 'glucose': 88, 'feedback': 'Excellent'}
#  {'id': 10, 'name': 'Fatima Sheikh', 'age': 44, 'doctor': 'Dr. Bilal', 'hr': 95, 'bp': '134/89', 'glucose': 130, 'feedback': 'Good'}
#  {'id': 11, 'name': 'Bilal Khan', 'age': 61, 'doctor': 'Dr. Sara', 'hr': 99, 'bp': '140/92', 'glucose': 155, 'feedback': 'Fair'}
#  {'id': 12, 'name': 'Khadija Amin', 'age': 36, 'doctor': 'Dr. Ahmed', 'hr': 85, 'bp': '128/84', 'glucose': 115, 'feedback': 'Good'}
#  {'id': 13, 'name': 'Zain Ali', 'age': 70, 'doctor': 'Dr. Noor', 'hr': 101, 'bp': '147/93', 'glucose': 162, 'feedback': 'Critical'}
#  {'id': 14, 'name': 'Sara Usman', 'age': 48, 'doctor': 'Dr. Bilal', 'hr': 78, 'bp': '122/80', 'glucose': 100, 'feedback': 'Excellent'}
#  {'id': 15, 'name': 'Adeel Ahmad', 'age': 55, 'doctor': 'Dr. Ahmed', 'hr': 92, 'bp': '130/85', 'glucose': 138, 'feedback': 'Fair'}
#  {'id': 16, 'name': 'Lubna Tariq', 'age': 32, 'doctor': 'Dr. Sara', 'hr': 87, 'bp': '125/83', 'glucose': 120, 'feedback': 'Good'}
#  {'id': 17, 'name': 'Irfan Malik', 'age': 68, 'doctor': 'Dr. Noor', 'hr': 108, 'bp': '150/95', 'glucose': 175, 'feedback': 'Critical'}
#  {'id': 18, 'name': 'Raheel Khan', 'age': 40, 'doctor': 'Dr. Ahmed', 'hr': 74, 'bp': '119/77', 'glucose': 93, 'feedback': 'Excellent'}
#  {'id': 19, 'name': 'Saima Noor', 'age': 59, 'doctor': 'Dr. Bilal', 'hr': 90, 'bp': '136/90', 'glucose': 143, 'feedback': 'Fair'}
#  {'id': 20, 'name': 'Taha Salman', 'age': 25, 'doctor': 'Dr. Sara', 'hr': 83, 'bp': '121/81', 'glucose': 108, 'feedback': 'Good'}
#  {'id': 21, 'name': 'Hira Asghar', 'age': 47, 'doctor': 'Dr. Ahmed', 'hr': 96, 'bp': '140/91', 'glucose': 150, 'feedback': 'Fair'}
#  {'id': 22, 'name': 'Zara Malik', 'age': 33, 'doctor': 'Dr. Noor', 'hr': 70, 'bp': '115/75', 'glucose': 85, 'feedback': 'Excellent'}
#  {'id': 23, 'name': 'Rizwan Ali', 'age': 62, 'doctor': 'Dr. Bilal', 'hr': 104, 'bp': '150/96', 'glucose': 168, 'feedback': 'Critical'}
#  {'id': 24, 'name': 'Shazia Ahmed', 'age': 58, 'doctor': 'Dr. Sara', 'hr': 88, 'bp': '129/84', 'glucose': 118, 'feedback': 'Good'}
#  {'id': 25, 'name': 'Muhammad Iqbal', 'age': 42, 'doctor': 'Dr. Ahmed', 'hr': 76, 'bp': '116/78', 'glucose': 97, 'feedback': 'Excellent'}
#  {'id': 26, 'name': 'Neha Khan', 'age': 37, 'doctor': 'Dr. Noor', 'hr': 91, 'bp': '132/86', 'glucose': 135, 'feedback': 'Good'}
#  {'id': 27, 'name': 'Ali Raza', 'age': 69, 'doctor': 'Dr. Bilal', 'hr': 107, 'bp': '152/97', 'glucose': 178, 'feedback': 'Critical'}
#  {'id': 28, 'name': 'Fahad Saleem', 'age': 51, 'doctor': 'Dr. Ahmed', 'hr': 80, 'bp': '124/82', 'glucose': 112, 'feedback': 'Good'}
#  {'id': 29, 'name': 'Mahnoor Shah', 'age': 60, 'doctor': 'Dr. Sara', 'hr': 98, 'bp': '141/93', 'glucose': 158, 'feedback': 'Fair'}
#  {'id': 30, 'name': 'Ammar Tariq', 'age': 30, 'doctor': 'Dr. Noor', 'hr': 75, 'bp': '118/78', 'glucose': 92, 'feedback': 'Excellent'}
#  {'id': 31, 'name': 'Sana Javed', 'age': 34, 'doctor': 'Dr. Bilal', 'hr': 90, 'bp': '130/88', 'glucose': 140, 'feedback': 'Fair'}
#  {'id': 32, 'name': 'Mubashir Ali', 'age': 57, 'doctor': 'Dr. Ahmed', 'hr': 103, 'bp': '148/94', 'glucose': 170, 'feedback': 'Critical'}
#  {'id': 33, 'name': 'Ayesha Khan', 'age': 46, 'doctor': 'Dr. Noor', 'hr': 82, 'bp': '125/83', 'glucose': 115, 'feedback': 'Good'}
#  {'id': 34, 'name': 'Omer Malik', 'age': 39, 'doctor': 'Dr. Sara', 'hr': 86, 'bp': '128/85', 'glucose': 122, 'feedback': 'Good'}
#  {'id': 35, 'name': 'Fatima Raza', 'age': 28, 'doctor': 'Dr. Ahmed', 'hr': 72, 'bp': '116/79', 'glucose': 97, 'feedback': 'Excellent'}
#  {'id': 36, 'name': 'Hammad Sheikh', 'age': 49, 'doctor': 'Dr. Bilal', 'hr': 94, 'bp': '137/90', 'glucose': 145, 'feedback': 'Fair'}
#  {'id': 37, 'name': 'Saba Malik', 'age': 64, 'doctor': 'Dr. Sara', 'hr': 106, 'bp': '151/97', 'glucose': 173, 'feedback': 'Critical'}
#  {'id': 38, 'name': 'Asad Ali', 'age': 41, 'doctor': 'Dr. Noor', 'hr': 77, 'bp': '120/80', 'glucose': 102, 'feedback': 'Good'}
#  {'id': 39, 'name': 'Naima Iqbal', 'age': 56, 'doctor': 'Dr. Ahmed', 'hr': 95, 'bp': '139/91', 'glucose': 150, 'feedback': 'Fair'}
#  {'id': 40, 'name': 'Waleed Khan', 'age': 62, 'doctor': 'Dr. Bilal', 'hr': 109, 'bp': '155/98', 'glucose': 180, 'feedback': 'Critical'}
#  {'id': 41, 'name': 'Anam Fatima', 'age': 43, 'doctor': 'Dr. Sara', 'hr': 78, 'bp': '122/81', 'glucose': 104, 'feedback': 'Good'}
#  {'id': 42, 'name': 'Adeel Qureshi', 'age': 38, 'doctor': 'Dr. Ahmed', 'hr': 92, 'bp': '133/87', 'glucose': 138, 'feedback': 'Fair'}
#  {'id': 43, 'name': 'Sara Ali', 'age': 29, 'doctor': 'Dr. Noor', 'hr': 74, 'bp': '119/78', 'glucose': 96, 'feedback': 'Excellent'}
#  {'id': 44, 'name': 'Talha Sharif', 'age': 66, 'doctor': 'Dr. Bilal', 'hr': 105, 'bp': '149/96', 'glucose': 168, 'feedback': 'Critical'}
#  {'id': 45, 'name': 'Madiha Khan', 'age': 61, 'doctor': 'Dr. Ahmed', 'hr': 89, 'bp': '135/89', 'glucose': 142, 'feedback': 'Fair'}
#  {'id': 46, 'name': 'Arslan Tariq', 'age': 31, 'doctor': 'Dr. Sara', 'hr': 73, 'bp': '116/76', 'glucose': 90, 'feedback': 'Excellent'}
#  {'id': 47, 'name': 'Rehan Ahmed', 'age': 52, 'doctor': 'Dr. Noor', 'hr': 97, 'bp': '141/92', 'glucose': 152, 'feedback': 'Fair'}
#  {'id': 48, 'name': 'Nida Malik', 'age': 48, 'doctor': 'Dr. Bilal', 'hr': 95, 'bp': '138/90', 'glucose': 148, 'feedback': 'Good'}
#  {'id': 49, 'name': 'Salman Khan', 'age': 40, 'doctor': 'Dr. Ahmed', 'hr': 84, 'bp': '124/83', 'glucose': 118, 'feedback': 'Good'}
#  {'id': 50, 'name': 'Uzma Raza', 'age': 58, 'doctor': 'Dr. Sara', 'hr': 103, 'bp': '146/95', 'glucose': 169, 'feedback': 'Critical'}

# %%
count=0
for id in structured_data:
    count+=1
print(count)
# Out:
# 50

# %%
doctors = set()
for Patient in structured_data:
    doctors.add(Patient['doctor'])

print("Average Heart Rate by Doctor:")
for doctor in doctors:
    total_hr = 0
    doctor_count = 0
    
    
    for Patient in structured_data:
        if Patient['doctor'] == doctor:
            total_hr += Patient['hr']
            doctor_count += 1
    
    
    avg_hr = total_hr / doctor_count
    print(f"  {doctor}: {avg_hr:.1f} bpm ({doctor_count} patients)")
# Out:
# Average Heart Rate by Doctor:
#   Dr. Bilal: 96.2 bpm (11 patients)
#   Dr. Sara: 93.7 bpm (13 patients)
#   Dr. Ahmed: 84.8 bpm (16 patients)
#   Dr. Noor: 87.2 bpm (10 patients)

# %%
high_risk = []

for Patient in structured_data:
    if Patient['hr'] > 100:
        high_risk.append(Patient)

print("High risk Patients:")
for Patient in high_risk:
        print(f"  ID {Patient['id']} {Patient['name']} with {Patient['hr']}")
# Out:
# High risk Patients:
#   ID 2 Ayesha Noor with 102
#   ID 5 Hamza Ali with 110
#   ID 8 Rida Aslam with 105
#   ID 13 Zain Ali with 101
#   ID 17 Irfan Malik with 108
#   ID 23 Rizwan Ali with 104
#   ID 27 Ali Raza with 107
#   ID 32 Mubashir Ali with 103
#   ID 37 Saba Malik with 106
#   ID 40 Waleed Khan with 109
#   ID 44 Talha Sharif with 105
#   ID 50 Uzma Raza with 103

# %%
min=500
for Patient in structured_data:
    if Patient['glucose']<min:
        min=Patient['glucose']
        Name=Patient['name']
print("Lowest glucose Level:")       
print(f" {Name} with lowest glucose level: {min}")
# Out:
# Lowest glucose Level:
#  Zara Malik with lowest glucose level: 85

# %%
max=0
for Patient in structured_data:
    if Patient['glucose']>max:
        max=Patient['glucose']
        Name=Patient['name']
print("Highest glucose Level:")
print(f" {Name} with glucose level: {max}")
# Out:
# Highest glucose Level:
#  Hamza Ali with glucose level: 180

# %%
high_bp_patients = []

for patient in structured_data:
    bp_parts = patient['bp'].split('/')
    s= int(bp_parts[0])    
    d = int(bp_parts[1])   
    if s > 140 or d > 90:
        high_bp_patients.append(patient)

print("Patients with high blood pressure:")
for patient in high_bp_patients:
    print(f"  {patient['name']} : BP: {patient['bp']}")
# Out:
# Patients with high blood pressure:
#   Ayesha Noor : BP: 145/95
#   Hamza Ali : BP: 150/92
#   Imran Hussain : BP: 142/90
#   Rida Aslam : BP: 149/94
#   Bilal Khan : BP: 140/92
#   Zain Ali : BP: 147/93
#   Irfan Malik : BP: 150/95
#   Hira Asghar : BP: 140/91
#   Rizwan Ali : BP: 150/96
#   Ali Raza : BP: 152/97
#   Mahnoor Shah : BP: 141/93
#   Mubashir Ali : BP: 148/94
#   Saba Malik : BP: 151/97
#   Naima Iqbal : BP: 139/91
#   Waleed Khan : BP: 155/98
#   Talha Sharif : BP: 149/96
#   Rehan Ahmed : BP: 141/92
#   Uzma Raza : BP: 146/95

# %%
dis_count = set()
for Patient in structured_data:
    dis_count.add(Patient['doctor'])
for doctor in dis_count:
    print(f"{doctor}")
# Out:
# Dr. Bilal
# Dr. Sara
# Dr. Ahmed
# Dr. Noor

# %%
feedback_count= {
    "Excellent": 0,
     "Good": 0, 
    "Fair": 0,
    "Critical": 0
}

for Patient in structured_data:  
    feedback_type = Patient['feedback'] 
    feedback_count[feedback_type] += 1  

print("Feedback distribution:")
for feedback_type, count in feedback_count.items():
    print(f"  {feedback_type}: {count} patients")
# Out:
# Feedback distribution:
#   Excellent: 10 patients
#   Good: 15 patients
#   Fair: 13 patients
#   Critical: 12 patients

# %%
sum=0
for Patient in structured_data:
    sum+=Patient['hr']
average=sum/len(structured_data)
print(average)
# Out:
# 90.08

# %%
health_grade_count = {
    "A": 0,
     "B": 0, 
    "C": 0,
    "D": 0
}

for Patient in structured_data:
    hr = Patient['hr'] 
    
    if hr < 70:
        health_grade = "A"
    elif 70 <= hr < 89:
        health_grade = "B"
    elif 90 <= hr < 110:
        health_grade = "C"
    else:
        health_grade = "D"
    
    health_grade_count[health_grade] += 1
    
for grade, count in health_grade_count.items():
    print(f"  Grade {grade}: {count} patients")
# Out:
#   Grade A: 0 patients
#   Grade B: 22 patients
#   Grade C: 26 patients
#   Grade D: 2 patients

# %%
improved_glucose_list = list(map(lambda patient: patient['glucose'] * 0.95, structured_data))

print("Improved glucose levels:")
for i, patient in enumerate(structured_data):
    original = patient['glucose']
    improved = improved_glucose_list[i]
    print(f"  {patient['name']}: {original} → {improved:.1f} ")
# Out:
# Improved glucose levels:
#   Ali Khan: 110 → 104.5
#   Ayesha Noor: 160 → 152.0
#   Usman Tariq: 95 → 90.2
#   Sana Fatima: 125 → 118.8
#   Hamza Ali: 180 → 171.0
#   Maryam Iqbal: 140 → 133.0
#   Imran Hussain: 165 → 156.8
#   Rida Aslam: 172 → 163.4
#   Hassan Raza: 88 → 83.6
#   Fatima Sheikh: 130 → 123.5
#   Bilal Khan: 155 → 147.2
#   Khadija Amin: 115 → 109.2
#   Zain Ali: 162 → 153.9
#   Sara Usman: 100 → 95.0
#   Adeel Ahmad: 138 → 131.1
#   Lubna Tariq: 120 → 114.0
#   Irfan Malik: 175 → 166.2
#   Raheel Khan: 93 → 88.3
#   Saima Noor: 143 → 135.8
#   Taha Salman: 108 → 102.6
#   Hira Asghar: 150 → 142.5
#   Zara Malik: 85 → 80.8
#   Rizwan Ali: 168 → 159.6
#   Shazia Ahmed: 118 → 112.1
#   Muhammad Iqbal: 97 → 92.1
#   Neha Khan: 135 → 128.2
#   Ali Raza: 178 → 169.1
#   Fahad Saleem: 112 → 106.4
#   Mahnoor Shah: 158 → 150.1
#   Ammar Tariq: 92 → 87.4
#   Sana Javed: 140 → 133.0
#   Mubashir Ali: 170 → 161.5
#   Ayesha Khan: 115 → 109.2
#   Omer Malik: 122 → 115.9
#   Fatima Raza: 97 → 92.1
#   Hammad Sheikh: 145 → 137.8
#   Saba Malik: 173 → 164.3
#   Asad Ali: 102 → 96.9
#   Naima Iqbal: 150 → 142.5
#   Waleed Khan: 180 → 171.0
#   Anam Fatima: 104 → 98.8
#   Adeel Qureshi: 138 → 131.1
#   Sara Ali: 96 → 91.2
#   Talha Sharif: 168 → 159.6
#   Madiha Khan: 142 → 134.9
#   Arslan Tariq: 90 → 85.5
#   Rehan Ahmed: 152 → 144.4
#   Nida Malik: 148 → 140.6
#   Salman Khan: 118 → 112.1
#   Uzma Raza: 169 → 160.5

# %%
doctors = set()
for Patient in structured_data:
    doctors.add(Patient['doctor'])

print("Average Heart Rate by Doctor:")
for doctor in doctors:
    total_hr = 0
    doctor_count = 0
    total_glucose=0
    
    for Patient in structured_data:
        if Patient['doctor'] == doctor:
            total_hr += Patient['hr']
            doctor_count += 1
            total_glucose+=Patient['glucose']
    
    avg_hr = total_hr / doctor_count
    avg_glucose=total_glucose/doctor_count
    print(f"  {doctor}: {avg_hr:.1f} bpm, {avg_glucose:.1f} glucose ({doctor_count} patients)")
# Out:
# Average Heart Rate by Doctor:
#   Dr. Bilal: 96.2 bpm, 147.7 glucose (11 patients)
#   Dr. Sara: 93.7 bpm, 140.7 glucose (13 patients)
#   Dr. Ahmed: 84.8 bpm, 122.1 glucose (16 patients)
#   Dr. Noor: 87.2 bpm, 127.9 glucose (10 patients)

# %%
Senior_Patients=[]
for Patient in structured_data:
    if Patient['age']>=60:
       Senior_Patients.append(Patient)
for Patient in Senior_Patients:
    print(f"  {Patient['name']} : {Patient['age']}")
# Out:
#   Ayesha Noor : 63
#   Maryam Iqbal : 71
#   Imran Hussain : 66
#   Bilal Khan : 61
#   Zain Ali : 70
#   Irfan Malik : 68
#   Rizwan Ali : 62
#   Ali Raza : 69
#   Mahnoor Shah : 60
#   Saba Malik : 64
#   Waleed Khan : 62
#   Talha Sharif : 66
#   Madiha Khan : 61

# %%
for Patient in structured_data:
    systolic, diastolic = map(int, Patient['bp'].split('/'))
    condition = "Severe" if (systolic > 140 or diastolic > 90 or Patient['feedback'] == "Critical") else "Normal"
    print(f"  {Patient['name']}: {condition}")
# Out:
#   Ali Khan: Normal
#   Ayesha Noor: Severe
#   Usman Tariq: Normal
#   Sana Fatima: Normal
#   Hamza Ali: Severe
#   Maryam Iqbal: Normal
#   Imran Hussain: Severe
#   Rida Aslam: Severe
#   Hassan Raza: Normal
#   Fatima Sheikh: Normal
#   Bilal Khan: Severe
#   Khadija Amin: Normal
#   Zain Ali: Severe
#   Sara Usman: Normal
#   Adeel Ahmad: Normal
#   Lubna Tariq: Normal
#   Irfan Malik: Severe
#   Raheel Khan: Normal
#   Saima Noor: Normal
#   Taha Salman: Normal
#   Hira Asghar: Severe
#   Zara Malik: Normal
#   Rizwan Ali: Severe
#   Shazia Ahmed: Normal
#   Muhammad Iqbal: Normal
#   Neha Khan: Normal
#   Ali Raza: Severe
#   Fahad Saleem: Normal
#   Mahnoor Shah: Severe
#   Ammar Tariq: Normal
#   Sana Javed: Normal
#   Mubashir Ali: Severe
#   Ayesha Khan: Normal
#   Omer Malik: Normal
#   Fatima Raza: Normal
#   Hammad Sheikh: Normal
#   Saba Malik: Severe
#   Asad Ali: Normal
#   Naima Iqbal: Severe
#   Waleed Khan: Severe
#   Anam Fatima: Normal
#   Adeel Qureshi: Normal
#   Sara Ali: Normal
#   Talha Sharif: Severe
#   Madiha Khan: Normal
#   Arslan Tariq: Normal
#   Rehan Ahmed: Severe
#   Nida Malik: Normal
#   Salman Khan: Normal
#   Uzma Raza: Severe

# %%
sorted_patients = structured_data.copy()
sorted_patients.sort(key=lambda x: x['age'], reverse=True)

for patient in sorted_patients:
    print(f"  {patient['name']} - {patient['age']} years")
# Out:
#   Maryam Iqbal - 71 years
#   Zain Ali - 70 years
#   Ali Raza - 69 years
#   Irfan Malik - 68 years
#   Imran Hussain - 66 years
#   Talha Sharif - 66 years
#   Saba Malik - 64 years
#   Ayesha Noor - 63 years
#   Rizwan Ali - 62 years
#   Waleed Khan - 62 years
#   Bilal Khan - 61 years
#   Madiha Khan - 61 years
#   Mahnoor Shah - 60 years
#   Saima Noor - 59 years
#   Shazia Ahmed - 58 years
#   Uzma Raza - 58 years
#   Mubashir Ali - 57 years
#   Naima Iqbal - 56 years
#   Adeel Ahmad - 55 years
#   Rida Aslam - 54 years
#   Usman Tariq - 52 years
#   Rehan Ahmed - 52 years
#   Fahad Saleem - 51 years
#   Hammad Sheikh - 49 years
#   Sara Usman - 48 years
#   Nida Malik - 48 years
#   Hira Asghar - 47 years
#   Ayesha Khan - 46 years
#   Ali Khan - 45 years
#   Fatima Sheikh - 44 years
#   Anam Fatima - 43 years
#   Muhammad Iqbal - 42 years
#   Asad Ali - 41 years
#   Raheel Khan - 40 years
#   Salman Khan - 40 years
#   Omer Malik - 39 years
#   Hamza Ali - 38 years
#   Adeel Qureshi - 38 years
#   Neha Khan - 37 years
#   Khadija Amin - 36 years
#   Sana Javed - 34 years
#   Zara Malik - 33 years
#   Lubna Tariq - 32 years
#   Arslan Tariq - 31 years
#   Ammar Tariq - 30 years
#   Sana Fatima - 29 years
#   Sara Ali - 29 years
#   Fatima Raza - 28 years
#   Hassan Raza - 27 years
#   Taha Salman - 25 years

# %%
for Patient in structured_data:
    hr = Patient['hr'] 
    if hr<90 and (Patient['feedback']=="Fair" or Patient['feedback']=="Critical"):
        print(f"  {Patient['name']}: {Patient['hr']} , {Patient['feedback']} ")
# Out:
#   Maryam Iqbal: 82 , Fair
#   Madiha Khan: 89 , Fair

# %%
count = 0
print("Feedback in lowercase:")
for Patient in structured_data:
    original_feedback = Patient['feedback']
    lowercase_feedback = original_feedback.lower() 
    
    if lowercase_feedback == "critical":  
        count += 1
    
    print(f"  {Patient['name']}: {lowercase_feedback}")

print(f"\nTotal 'critical' feedbacks: {count}")
# Out:
# Feedback in lowercase:
#   Ali Khan: good
#   Ayesha Noor: critical
#   Usman Tariq: excellent
#   Sana Fatima: good
#   Hamza Ali: critical
#   Maryam Iqbal: fair
#   Imran Hussain: fair
#   Rida Aslam: critical
#   Hassan Raza: excellent
#   Fatima Sheikh: good
#   Bilal Khan: fair
#   Khadija Amin: good
#   Zain Ali: critical
#   Sara Usman: excellent
#   Adeel Ahmad: fair
#   Lubna Tariq: good
#   Irfan Malik: critical
#   Raheel Khan: excellent
#   Saima Noor: fair
#   Taha Salman: good
#   Hira Asghar: fair
#   Zara Malik: excellent
#   Rizwan Ali: critical
#   Shazia Ahmed: good
#   Muhammad Iqbal: excellent
#   Neha Khan: good
#   Ali Raza: critical
#   Fahad Saleem: good
#   Mahnoor Shah: fair
#   Ammar Tariq: excellent
#   Sana Javed: fair
#   Mubashir Ali: critical
#   Ayesha Khan: good
#   Omer Malik: good
#   Fatima Raza: excellent
#   Hammad Sheikh: fair
#   Saba Malik: critical
#   Asad Ali: good
#   Naima Iqbal: fair
#   Waleed Khan: critical
#   Anam Fatima: good
#   Adeel Qureshi: fair
#   Sara Ali: excellent
#   Talha Sharif: critical
#   Madiha Khan: fair
#   Arslan Tariq: excellent
#   Rehan Ahmed: fair
#   Nida Malik: good
#   Salman Khan: good
#   Uzma Raza: critical
#
# Total 'critical' feedbacks: 12

# %%
doctors = {}
for Patient in structured_data:
    doctor = Patient['doctor']
    if doctor in doctors:
        doctors[doctor] += 1
    else:
        doctors[doctor] = 1

print("Doctor workload analysis:")
for doctor, count in doctors.items():
    if count>10:
        status="Overworked"
    elif count >= 2:
        status = "Optimal"
    else:
        status = "Understaffed"
    
    print(f"  {doctor}: {count} patients → {status}")
# Out:
# Doctor workload analysis:
#   Dr. Ahmed: 16 patients → Overworked
#   Dr. Sara: 13 patients → Overworked
#   Dr. Bilal: 11 patients → Overworked
#   Dr. Noor: 10 patients → Optimal

# %%
print("Patient Summary Cards:")
for Patient in structured_data:
    print(f"  {Patient['name']} | {Patient['age']} yrs | {Patient['doctor']} | HR:{Patient['hr']} | BP:{Patient['bp']} | Glucose:{Patient['glucose']} | Feedback:{Patient['feedback']}")
# Out:
# Patient Summary Cards:
#   Ali Khan | 45 yrs | Dr. Ahmed | HR:88 | BP:120/80 | Glucose:110 | Feedback:Good
#   Ayesha Noor | 63 yrs | Dr. Sara | HR:102 | BP:145/95 | Glucose:160 | Feedback:Critical
#   Usman Tariq | 52 yrs | Dr. Ahmed | HR:76 | BP:118/78 | Glucose:95 | Feedback:Excellent
#   Sana Fatima | 29 yrs | Dr. Bilal | HR:91 | BP:130/85 | Glucose:125 | Feedback:Good
#   Hamza Ali | 38 yrs | Dr. Sara | HR:110 | BP:150/92 | Glucose:180 | Feedback:Critical
#   Maryam Iqbal | 71 yrs | Dr. Ahmed | HR:82 | BP:135/88 | Glucose:140 | Feedback:Fair
#   Imran Hussain | 66 yrs | Dr. Noor | HR:97 | BP:142/90 | Glucose:165 | Feedback:Fair
#   Rida Aslam | 54 yrs | Dr. Sara | HR:105 | BP:149/94 | Glucose:172 | Feedback:Critical
#   Hassan Raza | 27 yrs | Dr. Ahmed | HR:72 | BP:117/79 | Glucose:88 | Feedback:Excellent
#   Fatima Sheikh | 44 yrs | Dr. Bilal | HR:95 | BP:134/89 | Glucose:130 | Feedback:Good
#   Bilal Khan | 61 yrs | Dr. Sara | HR:99 | BP:140/92 | Glucose:155 | Feedback:Fair
#   Khadija Amin | 36 yrs | Dr. Ahmed | HR:85 | BP:128/84 | Glucose:115 | Feedback:Good
#   Zain Ali | 70 yrs | Dr. Noor | HR:101 | BP:147/93 | Glucose:162 | Feedback:Critical
#   Sara Usman | 48 yrs | Dr. Bilal | HR:78 | BP:122/80 | Glucose:100 | Feedback:Excellent
#   Adeel Ahmad | 55 yrs | Dr. Ahmed | HR:92 | BP:130/85 | Glucose:138 | Feedback:Fair
#   Lubna Tariq | 32 yrs | Dr. Sara | HR:87 | BP:125/83 | Glucose:120 | Feedback:Good
#   Irfan Malik | 68 yrs | Dr. Noor | HR:108 | BP:150/95 | Glucose:175 | Feedback:Critical
#   Raheel Khan | 40 yrs | Dr. Ahmed | HR:74 | BP:119/77 | Glucose:93 | Feedback:Excellent
#   Saima Noor | 59 yrs | Dr. Bilal | HR:90 | BP:136/90 | Glucose:143 | Feedback:Fair
#   Taha Salman | 25 yrs | Dr. Sara | HR:83 | BP:121/81 | Glucose:108 | Feedback:Good
#   Hira Asghar | 47 yrs | Dr. Ahmed | HR:96 | BP:140/91 | Glucose:150 | Feedback:Fair
#   Zara Malik | 33 yrs | Dr. Noor | HR:70 | BP:115/75 | Glucose:85 | Feedback:Excellent
#   Rizwan Ali | 62 yrs | Dr. Bilal | HR:104 | BP:150/96 | Glucose:168 | Feedback:Critical
#   Shazia Ahmed | 58 yrs | Dr. Sara | HR:88 | BP:129/84 | Glucose:118 | Feedback:Good
#   Muhammad Iqbal | 42 yrs | Dr. Ahmed | HR:76 | BP:116/78 | Glucose:97 | Feedback:Excellent
#   Neha Khan | 37 yrs | Dr. Noor | HR:91 | BP:132/86 | Glucose:135 | Feedback:Good
#   Ali Raza | 69 yrs | Dr. Bilal | HR:107 | BP:152/97 | Glucose:178 | Feedback:Critical
#   Fahad Saleem | 51 yrs | Dr. Ahmed | HR:80 | BP:124/82 | Glucose:112 | Feedback:Good
#   Mahnoor Shah | 60 yrs | Dr. Sara | HR:98 | BP:141/93 | Glucose:158 | Feedback:Fair
#   Ammar Tariq | 30 yrs | Dr. Noor | HR:75 | BP:118/78 | Glucose:92 | Feedback:Excellent
#   Sana Javed | 34 yrs | Dr. Bilal | HR:90 | BP:130/88 | Glucose:140 | Feedback:Fair
#   Mubashir Ali | 57 yrs | Dr. Ahmed | HR:103 | BP:148/94 | Glucose:170 | Feedback:Critical
#   Ayesha Khan | 46 yrs | Dr. Noor | HR:82 | BP:125/83 | Glucose:115 | Feedback:Good
#   Omer Malik | 39 yrs | Dr. Sara | HR:86 | BP:128/85 | Glucose:122 | Feedback:Good
#   Fatima Raza | 28 yrs | Dr. Ahmed | HR:72 | BP:116/79 | Glucose:97 | Feedback:Excellent
#   Hammad Sheikh | 49 yrs | Dr. Bilal | HR:94 | BP:137/90 | Glucose:145 | Feedback:Fair
#   Saba Malik | 64 yrs | Dr. Sara | HR:106 | BP:151/97 | Glucose:173 | Feedback:Critical
#   Asad Ali | 41 yrs | Dr. Noor | HR:77 | BP:120/80 | Glucose:102 | Feedback:Good
#   Naima Iqbal | 56 yrs | Dr. Ahmed | HR:95 | BP:139/91 | Glucose:150 | Feedback:Fair
#   Waleed Khan | 62 yrs | Dr. Bilal | HR:109 | BP:155/98 | Glucose:180 | Feedback:Critical
#   Anam Fatima | 43 yrs | Dr. Sara | HR:78 | BP:122/81 | Glucose:104 | Feedback:Good
#   Adeel Qureshi | 38 yrs | Dr. Ahmed | HR:92 | BP:133/87 | Glucose:138 | Feedback:Fair
#   Sara Ali | 29 yrs | Dr. Noor | HR:74 | BP:119/78 | Glucose:96 | Feedback:Excellent
#   Talha Sharif | 66 yrs | Dr. Bilal | HR:105 | BP:149/96 | Glucose:168 | Feedback:Critical
#   Madiha Khan | 61 yrs | Dr. Ahmed | HR:89 | BP:135/89 | Glucose:142 | Feedback:Fair
#   Arslan Tariq | 31 yrs | Dr. Sara | HR:73 | BP:116/76 | Glucose:90 | Feedback:Excellent
#   Rehan Ahmed | 52 yrs | Dr. Noor | HR:97 | BP:141/92 | Glucose:152 | Feedback:Fair
#   Nida Malik | 48 yrs | Dr. Bilal | HR:95 | BP:138/90 | Glucose:148 | Feedback:Good
#   Salman Khan | 40 yrs | Dr. Ahmed | HR:84 | BP:124/83 | Glucose:118 | Feedback:Good
#   Uzma Raza | 58 yrs | Dr. Sara | HR:103 | BP:146/95 | Glucose:169 | Feedback:Critical
